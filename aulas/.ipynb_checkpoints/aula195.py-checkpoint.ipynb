# %% [markdown]
# # This is my title<!--  -->
# this line creates a variable `a`.

# %%
a = 2
a
# Out:
# 2

# %% [markdown]
# This one has the variable value `a` in double:

# %%
b = a * 2
b
# Out:
# 4

# %% [markdown]
# This one shows the value of `a` + `b`

# %%
a + b
# Out:
# 6
